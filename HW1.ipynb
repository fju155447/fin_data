# %%
X = 10
print(X)
type(X)
# Out:
# 10
# int

# %%
Y = 10.0
print(Y)
type(Y)
# Out:
# 10.0
# float

# %%
Z = X + Y
print(Z)
type(Z)
# Out:
# 20.0
# float

# %%
print(0b10)
# Out:
# 2

# %%
print(0o10)
# Out:
# 8

# %%
print(0o11)
# Out:
# 9

# %%
print(0x10)
# Out:
# 16

# %%
print(0x1A)
# Out:
# 26

# %%
x = 10
hex(x)
# Out:
# '0xa'

# %%
y = 0o10
bin(y)
# Out:
# '0b1000'

# %%
z = 0b11111
oct(z)
# Out:
# '0o37'

# %%
X = True
print(X)
type(X)
# Out:
# True
# bool

# %%
int(X)
# Out:
# 1

# %%
Y = False
print(Y)
type(Y)
int(Y)
# Out:
# False
# 0

# %%
Z = X + Y
print(Z)
type(Z)
# Out:
# 1
# int

# %%
X = 'a'
print(X)
type(X)
len(X)
# Out:
# a
# 1

# %%
type(X)
# Out:
# str

# %%
Y = "usage"
print(Y)
type(Y)
len(Y)
# Out:
# usage
# 5

# %%
a='1'
b=2
a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 a='1'
#       2 b=2
# ----> 3 a+b
#
# TypeError: can only concatenate str (not "int") to str

# %%
concate(a,b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 concate(a,b)
#
# NameError: name 'concate' is not defined

# %%
X = 'a'
Y = 'usage'
X+Y
X*3
# Out:
# 'aaa'

# %%
X+Y
# Out:
# 'ausage'

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_excel("C:\\Users\\10235\\Downloads\\20220909-global-financial-development-database.xlsx", sheet_name="Data - November 2021")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#       iso3 iso2  imfn   country                     region  \
# 0      ABW   AW   314     Aruba  Latin America & Caribbean
# 1      ABW   AW   314     Aruba  Latin America & Caribbean
# 2      ABW   AW   314     Aruba  Latin America & Caribbean
# 3      ABW   AW   314     Aruba  Latin America & Caribbean
# 4      ABW   AW   314     Aruba  Latin America & Caribbean
# ...    ...  ...   ...       ...                        ...
# 13049  ZWE   ZW   698  Zimbabwe         Sub-Saharan Africa
# 13050  ZWE   ZW   698  Zimbabwe         Sub-Saharan Africa
# 13051  ZWE   ZW   698  Zimbabwe         Sub-Saharan Africa
# 13052  ZWE   ZW   698  Zimbabwe         Sub-Saharan Africa
# 13053  ZWE   ZW   698  Zimbabwe         Sub-Saharan Africa
#
#                     income  year      ai01      ai02  ai03  ...  oi14  oi15  \
# 0              High income  1960       NaN       NaN   NaN  ...   NaN   NaN
# 1              High income  1961       NaN       NaN   NaN  ...   NaN   NaN
# ...

# %%
print(df)
# Out:
#       iso3 iso2  imfn   country                     region  \
# 0      ABW   AW   314     Aruba  Latin America & Caribbean
# 1      ABW   AW   314     Aruba  Latin America & Caribbean
# 2      ABW   AW   314     Aruba  Latin America & Caribbean
# 3      ABW   AW   314     Aruba  Latin America & Caribbean
# 4      ABW   AW   314     Aruba  Latin America & Caribbean
# ...    ...  ...   ...       ...                        ...
# 13049  ZWE   ZW   698  Zimbabwe         Sub-Saharan Africa
# 13050  ZWE   ZW   698  Zimbabwe         Sub-Saharan Africa
# 13051  ZWE   ZW   698  Zimbabwe         Sub-Saharan Africa
# 13052  ZWE   ZW   698  Zimbabwe         Sub-Saharan Africa
# 13053  ZWE   ZW   698  Zimbabwe         Sub-Saharan Africa
#
#                     income  year      ai01      ai02  ai03  ...  oi14  oi15  \
# 0              High income  1960       NaN       NaN   NaN  ...   NaN   NaN
# 1              High income  1961       NaN       NaN   NaN  ...   NaN   NaN
# ...

# %%
a = "C:\\Users\\10235\\Downloads\\20220909-global-financial-development-database.xlsx"
b = "Data - November 2021"

# %%
df = pd.read_excel(a, sheet_name=b)

# %%
# !pip install yfinance
# Out:
# ...
#   Obtaining dependency information for yfinance from https://files.pythonhosted.org/packages/14/03/3c854ca3e02eedf614abba4b2e177c469bf3af58207fa30d5098c5d652fe/yfinance-0.2.37-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for multitasking>=0.0.7 from https://files.pythonhosted.org/packages/3e/8a/bb3160e76e844db9e69a413f055818969c8acade64e1a9ac5ce9dfdcf6c1/multitasking-0.0.11-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/315.2 kB ? eta -:--:--
#      - -------------------------------------- 10.2/315.2 kB ? eta -:--:--
#      --- --------------------------------- 30.7/315.2 kB 660.6 kB/s eta 0:00:01
#      --- --------------------------------- 30.7/315.2 kB 660.6 kB/s eta 0:00:01
#      ------- ----------------------------- 61.4/315.2 kB 363.1 kB/s eta 0:00:01
#      ---------- -------------------------- 92.2/315.2 kB 435.7 kB/s eta 0:00:01
#      ------------ ----------------------- 112.6/315.2 kB 467.6 kB/s eta 0:00:01
# ...

# %%
import yfinance as yf

# %%
df = yf.download("2330.TW", "2022-06-27")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#              Open   High    Low  Close   Adj Close    Volume
# Date
# 2022-06-27  496.0  506.0  495.5  498.5  480.399872  37909718
# 2022-06-28  496.0  500.0  496.0  497.5  479.436127  15274062
# 2022-06-29  496.0  498.5  491.0  491.0  473.172180  30533789
# 2022-06-30  484.5  486.5  476.0  476.0  458.716797  46311432
# 2022-07-01  471.5  474.0  452.5  453.5  437.033722  61744377
# ...           ...    ...    ...    ...         ...       ...
# 2024-04-03  783.0  785.0  778.0  780.0  780.000000  30890544
# 2024-04-08  789.0  792.0  783.0  783.0  783.000000  32202226
# 2024-04-09  795.0  820.0  792.0  819.0  819.000000  56857731
# 2024-04-10  815.0  819.0  810.0  815.0  815.000000  27480849
# 2024-04-11  811.0  820.0  811.0  820.0  820.000000  25782821
#
# [435 rows x 6 columns]

# %%
df.to_excel('yahoo_2330TW.xlsx')

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\10235'

# %%
# !pip install ucimlrepo
# Out:
# ...
#   Obtaining dependency information for ucimlrepo from https://files.pythonhosted.org/packages/22/47/9350b2eeeaef8c0fd3ec3505c8a0481b576845b3df0d71c76f989c23d3c6/ucimlrepo-0.0.6-py3-none-any.whl.metadata
# ...

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
default_of_credit_card_clients = fetch_ucirepo(id=350)

# %%
type(default_of_credit_card_clients)
# Out:
# ucimlrepo.dotdict.dotdict

# %%
default_of_credit_card_clients
# Out:
# {'data': {'ids':           ID
#   0          1
#   1          2
#   2          3
#   3          4
#   4          5
#   ...      ...
#   29995  29996
#   29996  29997
#   29997  29998
#   29998  29999
#   29999  30000
#
#   [30000 rows x 1 columns],
#   'features':            X1  X2  X3  X4  X5  X6  X7  X8  X9  X10  ...     X14    X15    X16  \
#   0       20000   2   2   1  24   2   2  -1  -1   -2  ...     689      0      0
#   1      120000   2   2   2  26  -1   2   0   0    0  ...    2682   3272   3455
#   2       90000   2   2   2  34   0   0   0   0    0  ...   13559  14331  14948
#   3       50000   2   2   1  37   0   0   0   0    0  ...   49291  28314  28959
#   4       50000   1   2   1  57  -1   0  -1   0    0  ...   35835  20940  19146
#   ...       ...  ..  ..  ..  ..  ..  ..  ..  ..  ...  ...     ...    ...    ...
#   29995  220000   1   3   1  39   0   0   0   0    0  ...  208365  88004  31237
# ...

# %%
from ucimlrepo import fetch_ucirepo, list_available_datasets

# %%
list_available_datasets()
# Out:
# -------------------------------------
# The following datasets are available:
# -------------------------------------
# Dataset Name                                                                            ID
# ------------                                                                            --
# Abalone                                                                                 1
# Adult                                                                                   2
# Annealing                                                                               3
# Audiology (Standardized)                                                                8
# Auto MPG                                                                                9
# Automobile                                                                              10
# Balance Scale                                                                           12
# ...

# %%
# data (as pandas dataframes) 
X = default_of_credit_card_clients.data.features
y = default_of_credit_card_clients.data.targets

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.frame.DataFrame

# %%
X
# Out:
#            X1  X2  X3  X4  X5  X6  X7  X8  X9  X10  ...     X14    X15    X16  \
# 0       20000   2   2   1  24   2   2  -1  -1   -2  ...     689      0      0
# 1      120000   2   2   2  26  -1   2   0   0    0  ...    2682   3272   3455
# 2       90000   2   2   2  34   0   0   0   0    0  ...   13559  14331  14948
# 3       50000   2   2   1  37   0   0   0   0    0  ...   49291  28314  28959
# 4       50000   1   2   1  57  -1   0  -1   0    0  ...   35835  20940  19146
# ...       ...  ..  ..  ..  ..  ..  ..  ..  ..  ...  ...     ...    ...    ...
# 29995  220000   1   3   1  39   0   0   0   0    0  ...  208365  88004  31237
# 29996  150000   1   3   2  43  -1  -1  -1  -1    0  ...    3502   8979   5190
# 29997   30000   1   2   2  37   4   3   2  -1    0  ...    2758  20878  20582
# 29998   80000   1   3   1  41   1  -1   0   0    0  ...   76304  52774  11855
# 29999   50000   1   2   1  46   0   0   0   0    0  ...   49764  36535  32428
#
# ...
